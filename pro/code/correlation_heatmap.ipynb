# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("merge_df.csv")
data.head()
# Out:
#    tokennum  celexfreq  syllstart   syllend  wordstart   wordend  tokenstart  \
# 0 -1.358375  -0.498477  -0.787584 -0.788024  -0.787351 -0.786880   -0.787439
# 1 -1.358299  -0.460607  -0.593587 -0.593517  -0.593122 -0.593417   -0.593438
# 2 -1.358224  -0.491563  -0.582481 -0.582631  -0.583497 -0.582529   -0.582330
# 3 -1.358148  -0.515879  -0.577969 -0.577425  -0.577500 -0.577322   -0.577754
# 4 -1.358073   0.202558  -0.574397 -0.574926  -0.573928 -0.574823   -0.574276
#
#    tokenend  corpusfreq  tokendur  ...    bw3_40    bw3_45    bw3_50  \
# 0 -0.787707   -0.594113 -0.931524  ... -0.549589 -0.504159 -0.300810
# 1 -0.593289   -0.466431  0.208785  ... -0.995314 -0.857803 -0.883122
# 2 -0.582275   -0.641154  0.121069  ... -0.625203 -0.448840 -0.454733
# 3 -0.577068   -0.503391  0.705843  ... -1.043070 -1.049443 -1.012937
# 4 -0.574569    3.439642 -0.200557  ... -0.696838 -0.699750 -0.675418
#
#      bw3_55    bw3_60    bw3_65    bw3_70    bw3_75    bw3_80  token_encoded
# 0  1.108861  1.234942 -0.893439  2.593506 -0.665470 -0.540583              1
# 1 -0.938368 -0.983384 -0.952136 -0.956168 -0.661609 -0.591236              1
# 2 -0.466837 -0.614331  0.274648  0.727801 -0.260039 -0.104187              1
# 3 -1.052321 -0.947281 -0.934527 -0.938767 -1.007191 -0.947755              1
# 4 -0.633838 -0.564188 -0.470814 -0.393556 -0.356570 -0.339919              1
#
# [5 rows x 50 columns]

# %%
corr = data.corr()
plt.figure(figsize=(50,50))
sns.heatmap(corr,annot=True, square=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>
